# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# *Step 1. Importing the required libraries*

# %%
! pip install numpy pandas scikit-learn matplotlib

# %%
import numpy as np ## linear algebra
import pandas as pd ## data processing, data transformation,data cleaning
from sklearn.linear_model import LinearRegression ## Use to perform linear 
import matplotlib.pyplot as plt ## Use to plot the data

# %% [markdown]
# Experimenting with random data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import numpy as np

# %%
randomdata = np.random.RandomState(1)
x = 10 * randomdata.rand(50)
y = 2 * x - 5 + randomdata.rand(50)
plt.scatter(x, y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x[:, np.newaxis], y)
xfit = np.linspace(0, 10, 100)
yfit = model.predict(xfit[:, np.newaxis])
plt.scatter(x, y)
plt.plot(xfit, yfit, color='green')
